# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# Binary Classification - Data Preparation

# %%
df = pd.read_csv("/workspaces/ml-zoomcamp-hw/03-Classification/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# StreamingTV                     No            No              No
# StreamingMovies                 No            No              No
# Contract            Month-to-month      One year  Month-to-month
# PaperlessBilling               Yes            No             Yes
# PaymentMethod     Electronic check  Mailed check    Mailed check
# MonthlyCharges               29.85         56.95           53.85
# TotalCharges                 29.85        1889.5          108.15
# Churn                           No            No             Yes
#
#                                           3                 4
# customerID                       7795-CFOCW        9237-HQITU
# gender                                 Male            Female
# SeniorCitizen                             0                 0
# Partner                                  No                No
# Dependents                               No                No
# tenure                                   45                 2
# PhoneService                             No               Yes
# MultipleLines              No phone service                No
# InternetService                         DSL       Fiber optic
# OnlineSecurity                          Yes                No
# OnlineBackup                             No                No
# DeviceProtection                        Yes                No
# TechSupport                             Yes                No
# StreamingTV                              No                No
# StreamingMovies                          No                No
# Contract                           One year    Month-to-month
# PaperlessBilling                         No               Yes
# PaymentMethod     Bank transfer (automatic)  Electronic check
# MonthlyCharges                         42.3              70.7
# TotalCharges                        1840.75            151.65
# Churn                                    No               Yes

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

categorical_columns = list(df.dtypes[df.dtypes=='object'].index)

for c in categorical_columns:
    df[c] = df[c].str.lower().str.replace(' ', '_')

# %%
df.dtypes
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges         object
# churn                object
# dtype: object

# %%
df['totalcharges']= pd.to_numeric(df.totalcharges, errors='coerce')
df[df.totalcharges.isnull()][['customerid', 'totalcharges']]
# Out:
#       customerid  totalcharges
# 488   4472-lvygi           NaN
# 753   3115-czmzd           NaN
# 936   5709-lvoeq           NaN
# 1082  4367-nuyao           NaN
# 1340  1371-dwpaz           NaN
# 3331  7644-omvmy           NaN
# 3826  3213-vvolg           NaN
# 4380  2520-sgtta           NaN
# 5218  2923-arzlg           NaN
# 6670  4075-wkniu           NaN
# 6754  2775-sefee           NaN

# %%
df.totalcharges = df.totalcharges.fillna(0)

# %%
df.churn
# Out:
# 0        no
# 1        no
# 2       yes
# 3        no
# 4       yes
#        ...
# 7038     no
# 7039     no
# 7040     no
# 7041    yes
# 7042     no
# Name: churn, Length: 7043, dtype: object

# %%
df.churn = (df.churn == 'yes').astype(int)

# %% [markdown]
# Validation setup

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)

df_train, df_val = train_test_split(df_full_train, test_size= 0.25, random_state=1)

len(df_full_train), len(df_train), len(df_val,), len(df_test)
# Out:
# (5634, 4225, 1409, 1409)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.churn.values
y_val = df_val.churn.values
y_test = df_test.churn.values

# %%
del df_train['churn']
del df_val['churn']
del df_test['churn']

# %% [markdown]
# EDA

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
df_full_train['churn'].value_counts()
df_full_train.churn.value_counts(normalize=True)
# Out:
# churn
# 0    0.730032
# 1    0.269968
# Name: proportion, dtype: float64

# %%
global_churn_rate = df_full_train.churn.mean()
round(global_churn_rate, 2)
# Out:
# np.float64(0.27)

# %%
df_full_train.dtypes
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges        float64
# churn                 int64
# dtype: object

# %%
numerical = ['tenure', 'monthlycharges', 'totalcharges']
df_full_train.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %%
categorical = ['gender', 'seniorcitizen', 'partner', 'dependents', 'phoneservice', 'multiplelines', 'internetservice',
       'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
       'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
       'paymentmethod']

# %%
df_full_train[categorical].nunique()
# Out:
# gender              2
# seniorcitizen       2
# partner             2
# dependents          2
# phoneservice        2
# multiplelines       3
# internetservice     3
# onlinesecurity      3
# onlinebackup        3
# deviceprotection    3
# techsupport         3
# streamingtv         3
# streamingmovies     3
# contract            3
# paperlessbilling    2
# paymentmethod       4
# dtype: int64

# %%
sns.histplot(df_full_train['churn'])
# Out:
# <Axes: xlabel='churn', ylabel='Count'>

# %% [markdown]
# Churn Rate and Risk Ratio

# %%
df_full_train[df_full_train.gender == 'female']['churn'].mean()
# Out:
# np.float64(0.27682403433476394)

# %%
df_full_train[df_full_train.gender == 'male']['churn'].mean()
# Out:
# np.float64(0.2632135306553911)

# %%
global_churn_rate
# Out:
# np.float64(0.26996805111821087)

# %%
df_full_train.partner.value_counts()
# Out:
# partner
# no     2932
# yes    2702
# Name: count, dtype: int64

# %%
churn_male = df_full_train[df_full_train.gender == 'male']['churn'].mean()
churn_female = df_full_train[df_full_train.gender == 'female']['churn'].mean()

# %%
churn_with_partner = df_full_train[df_full_train.partner == 'yes']['churn'].mean()
churn_with_partner
# Out:
# np.float64(0.20503330866025166)

# %%
churn_no_partner = df_full_train[df_full_train.partner == 'no']['churn'].mean()
churn_no_partner
# Out:
# np.float64(0.3298090040927694)

# %%
global_churn_rate - churn_male
# Out:
# np.float64(0.006754520462819769)

# %% [markdown]
# #Feature importance, since we are looking at churn rate, comparing the global churn rate to the various churn rates of multiple groups
# #to figure out which groups differ from the global helps identify important features.

# %% [markdown]
# Group Difference

# %%
churn_no_partner/global_churn_rate
# Out:
# np.float64(1.2216593879412643)

# %%
churn_with_partner/global_churn_rate
# Out:
# np.float64(0.7594724924338315)

# %% [markdown]
# Risk Ratio = Group Churn Rate/Global Churn if greater than 1, more likely to churn, less than one, less likely to churn

# %%
from IPython.display import display

# %%
for c in categorical:
    print(c)
    df_group = df_full_train.groupby(c).churn.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_churn_rate
    df_group['risk'] = df_group['mean'] / global_churn_rate
    display(df_group)
# Out:
# gender
#             mean  count      diff      risk
# gender
# female  0.276824   2796  0.006856  1.025396
# male    0.263214   2838 -0.006755  0.974980
# seniorcitizen
#                    mean  count      diff      risk
# seniorcitizen
# 0              0.242270   4722 -0.027698  0.897403
# 1              0.413377    912  0.143409  1.531208
# partner
#              mean  count      diff      risk
# partner
# no       0.329809   2932  0.059841  1.221659
# yes      0.205033   2702 -0.064935  0.759472
# dependents
#                 mean  count      diff      risk
# dependents
# no          0.313760   3968  0.043792  1.162212
# yes         0.165666   1666 -0.104302  0.613651
# phoneservice
#                   mean  count      diff      risk
# phoneservice
# no            0.241316    547 -0.028652  0.893870
# yes           0.273049   5087  0.003081  1.011412
# multiplelines
#                       mean  count      diff      risk
# multiplelines
# no                0.257407   2700 -0.012561  0.953474
# no_phone_service  0.241316    547 -0.028652  0.893870
# yes               0.290742   2387  0.020773  1.076948
# internetservice
#                      mean  count      diff      risk
# internetservice
# dsl              0.192347   1934 -0.077621  0.712482
# fiber_optic      0.425171   2479  0.155203  1.574895
# no               0.077805   1221 -0.192163  0.288201
# onlinesecurity
#                          mean  count      diff      risk
# onlinesecurity
# no                   0.420921   2801  0.150953  1.559152
# no_internet_service  0.077805   1221 -0.192163  0.288201
# yes                  0.153226   1612 -0.116742  0.567570
# onlinebackup
#                          mean  count      diff      risk
# onlinebackup
# no                   0.404323   2498  0.134355  1.497672
# no_internet_service  0.077805   1221 -0.192163  0.288201
# yes                  0.217232   1915 -0.052736  0.804660
# deviceprotection
#                          mean  count      diff      risk
# deviceprotection
# no                   0.395875   2473  0.125907  1.466379
# no_internet_service  0.077805   1221 -0.192163  0.288201
# yes                  0.230412   1940 -0.039556  0.853480
# techsupport
#                          mean  count      diff      risk
# techsupport
# no                   0.418914   2781  0.148946  1.551717
# no_internet_service  0.077805   1221 -0.192163  0.288201
# yes                  0.159926   1632 -0.110042  0.592390
# streamingtv
#                          mean  count      diff      risk
# streamingtv
# no                   0.342832   2246  0.072864  1.269897
# no_internet_service  0.077805   1221 -0.192163  0.288201
# yes                  0.302723   2167  0.032755  1.121328
# streamingmovies
#                          mean  count      diff      risk
# streamingmovies
# no                   0.338906   2213  0.068938  1.255358
# no_internet_service  0.077805   1221 -0.192163  0.288201
# yes                  0.307273   2200  0.037305  1.138182
# contract
#                     mean  count      diff      risk
# contract
# month-to-month  0.431701   3104  0.161733  1.599082
# one_year        0.120573   1186 -0.149395  0.446621
# two_year        0.028274   1344 -0.241694  0.104730
# paperlessbilling
#                       mean  count      diff      risk
# paperlessbilling
# no                0.172071   2313 -0.097897  0.637375
# yes               0.338151   3321  0.068183  1.252560
# paymentmethod
#                                mean  count      diff      risk
# paymentmethod
# bank_transfer_(automatic)  0.168171   1219 -0.101797  0.622928
# credit_card_(automatic)    0.164339   1217 -0.105630  0.608733
# electronic_check           0.455890   1893  0.185922  1.688682
# mailed_check               0.193870   1305 -0.076098  0.718121

# %%
#Test code to save all the dif and risk values into a dataframe

df_group_test = pd.DataFrame()
categorical_test = ['gender', 'seniorcitizen', 'partner', 'dependents', 'phoneservice', 'multiplelines', 'internetservice',
       'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
       'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
       'paymentmethod']


for c in categorical_test:
    temp = (
        df_full_train
        .groupby(c, dropna=False)['churn']
        .agg(mean='mean', count='count')
        .reset_index()
    )

    temp['diff'] = temp['mean'] - global_churn_rate
    temp['risk'] = temp['mean'] / global_churn_rate
    temp['category'] = c

    # reorder columns so category comes first, value comes second
    #The value column is the values from the category c, we just rename it to values here. 
    temp = temp[['category', c, 'mean', 'count', 'diff', 'risk']]
    temp = temp.rename(columns={c: 'value'})

    # append to main df_group_test
    df_group_test = pd.concat([df_group_test, temp], ignore_index=True)

# final cleanup: drop index just to be safe if saving or exporting
df_group_test.reset_index(drop=True, inplace=True)

# %%
df_group_test
# Out:
#             category                      value      mean  count      diff  \
# 0             gender                     female  0.276824   2796  0.006856
# 1             gender                       male  0.263214   2838 -0.006755
# 2      seniorcitizen                          0  0.242270   4722 -0.027698
# 3      seniorcitizen                          1  0.413377    912  0.143409
# 4            partner                         no  0.329809   2932  0.059841
# 5            partner                        yes  0.205033   2702 -0.064935
# 6         dependents                         no  0.313760   3968  0.043792
# 7         dependents                        yes  0.165666   1666 -0.104302
# 8       phoneservice                         no  0.241316    547 -0.028652
# 9       phoneservice                        yes  0.273049   5087  0.003081
# 10     multiplelines                         no  0.257407   2700 -0.012561
# 11     multiplelines           no_phone_service  0.241316    547 -0.028652
# 12     multiplelines                        yes  0.290742   2387  0.020773
# 13   internetservice                        dsl  0.192347   1934 -0.077621
# 14   internetservice                fiber_optic  0.425171   2479  0.155203
# 15   internetservice                         no  0.077805   1221 -0.192163
# 16    onlinesecurity                         no  0.420921   2801  0.150953
# 17    onlinesecurity        no_internet_service  0.077805   1221 -0.192163
# 18    onlinesecurity                        yes  0.153226   1612 -0.116742
# 19      onlinebackup                         no  0.404323   2498  0.134355
# 20      onlinebackup        no_internet_service  0.077805   1221 -0.192163
# 21      onlinebackup                        yes  0.217232   1915 -0.052736
# 22  deviceprotection                         no  0.395875   2473  0.125907
# 23  deviceprotection        no_internet_service  0.077805   1221 -0.192163
# 24  deviceprotection                        yes  0.230412   1940 -0.039556
# 25       techsupport                         no  0.418914   2781  0.148946
# 26       techsupport        no_internet_service  0.077805   1221 -0.192163
# 27       techsupport                        yes  0.159926   1632 -0.110042
# 28       streamingtv                         no  0.342832   2246  0.072864
# 29       streamingtv        no_internet_service  0.077805   1221 -0.192163
# 30       streamingtv                        yes  0.302723   2167  0.032755
# 31   streamingmovies                         no  0.338906   2213  0.068938
# 32   streamingmovies        no_internet_service  0.077805   1221 -0.192163
# 33   streamingmovies                        yes  0.307273   2200  0.037305
# 34          contract             month-to-month  0.431701   3104  0.161733
# 35          contract                   one_year  0.120573   1186 -0.149395
# 36          contract                   two_year  0.028274   1344 -0.241694
# 37  paperlessbilling                         no  0.172071   2313 -0.097897
# 38  paperlessbilling                        yes  0.338151   3321  0.068183
# 39     paymentmethod  bank_transfer_(automatic)  0.168171   1219 -0.101797
# 40     paymentmethod    credit_card_(automatic)  0.164339   1217 -0.105630
# 41     paymentmethod           electronic_check  0.455890   1893  0.185922
# 42     paymentmethod               mailed_check  0.193870   1305 -0.076098
#
#         risk
# 0   1.025396
# 1   0.974980
# 2   0.897403
# 3   1.531208
# 4   1.221659
# 5   0.759472
# 6   1.162212
# 7   0.613651
# 8   0.893870
# 9   1.011412
# 10  0.953474
# 11  0.893870
# 12  1.076948
# 13  0.712482
# 14  1.574895
# 15  0.288201
# 16  1.559152
# 17  0.288201
# 18  0.567570
# 19  1.497672
# 20  0.288201
# 21  0.804660
# 22  1.466379
# 23  0.288201
# 24  0.853480
# 25  1.551717
# 26  0.288201
# 27  0.592390
# 28  1.269897
# 29  0.288201
# 30  1.121328
# 31  1.255358
# 32  0.288201
# 33  1.138182
# 34  1.599082
# 35  0.446621
# 36  0.104730
# 37  0.637375
# 38  1.252560
# 39  0.622928
# 40  0.608733
# 41  1.688682
# 42  0.718121

# %%
df_group_test.sort_values('risk', ascending=False)
# Out:
#             category                      value      mean  count      diff  \
# 41     paymentmethod           electronic_check  0.455890   1893  0.185922
# 34          contract             month-to-month  0.431701   3104  0.161733
# 14   internetservice                fiber_optic  0.425171   2479  0.155203
# 16    onlinesecurity                         no  0.420921   2801  0.150953
# 25       techsupport                         no  0.418914   2781  0.148946
# 3      seniorcitizen                          1  0.413377    912  0.143409
# 19      onlinebackup                         no  0.404323   2498  0.134355
# 22  deviceprotection                         no  0.395875   2473  0.125907
# 28       streamingtv                         no  0.342832   2246  0.072864
# 31   streamingmovies                         no  0.338906   2213  0.068938
# 38  paperlessbilling                        yes  0.338151   3321  0.068183
# 4            partner                         no  0.329809   2932  0.059841
# 6         dependents                         no  0.313760   3968  0.043792
# 33   streamingmovies                        yes  0.307273   2200  0.037305
# 30       streamingtv                        yes  0.302723   2167  0.032755
# 12     multiplelines                        yes  0.290742   2387  0.020773
# 0             gender                     female  0.276824   2796  0.006856
# 9       phoneservice                        yes  0.273049   5087  0.003081
# 1             gender                       male  0.263214   2838 -0.006755
# 10     multiplelines                         no  0.257407   2700 -0.012561
# 2      seniorcitizen                          0  0.242270   4722 -0.027698
# 8       phoneservice                         no  0.241316    547 -0.028652
# 11     multiplelines           no_phone_service  0.241316    547 -0.028652
# 24  deviceprotection                        yes  0.230412   1940 -0.039556
# 21      onlinebackup                        yes  0.217232   1915 -0.052736
# 5            partner                        yes  0.205033   2702 -0.064935
# 42     paymentmethod               mailed_check  0.193870   1305 -0.076098
# 13   internetservice                        dsl  0.192347   1934 -0.077621
# 37  paperlessbilling                         no  0.172071   2313 -0.097897
# 39     paymentmethod  bank_transfer_(automatic)  0.168171   1219 -0.101797
# 7         dependents                        yes  0.165666   1666 -0.104302
# 40     paymentmethod    credit_card_(automatic)  0.164339   1217 -0.105630
# 27       techsupport                        yes  0.159926   1632 -0.110042
# 18    onlinesecurity                        yes  0.153226   1612 -0.116742
# 35          contract                   one_year  0.120573   1186 -0.149395
# 26       techsupport        no_internet_service  0.077805   1221 -0.192163
# 23  deviceprotection        no_internet_service  0.077805   1221 -0.192163
# 20      onlinebackup        no_internet_service  0.077805   1221 -0.192163
# 17    onlinesecurity        no_internet_service  0.077805   1221 -0.192163
# 15   internetservice                         no  0.077805   1221 -0.192163
# 29       streamingtv        no_internet_service  0.077805   1221 -0.192163
# 32   streamingmovies        no_internet_service  0.077805   1221 -0.192163
# 36          contract                   two_year  0.028274   1344 -0.241694
#
#         risk
# 41  1.688682
# 34  1.599082
# 14  1.574895
# 16  1.559152
# 25  1.551717
# 3   1.531208
# 19  1.497672
# 22  1.466379
# 28  1.269897
# 31  1.255358
# 38  1.252560
# 4   1.221659
# 6   1.162212
# 33  1.138182
# 30  1.121328
# 12  1.076948
# 0   1.025396
# 9   1.011412
# 1   0.974980
# 10  0.953474
# 2   0.897403
# 8   0.893870
# 11  0.893870
# 24  0.853480
# 21  0.804660
# 5   0.759472
# 42  0.718121
# 13  0.712482
# 37  0.637375
# 39  0.622928
# 7   0.613651
# 40  0.608733
# 27  0.592390
# 18  0.567570
# 35  0.446621
# 26  0.288201
# 23  0.288201
# 20  0.288201
# 17  0.288201
# 15  0.288201
# 29  0.288201
# 32  0.288201
# 36  0.104730

# %% [markdown]
# Feature Importance - Mutual Information
# Mutual information quantifies the amount of information that one variable contains about another — it measures the degree of dependency between the two.

# %%
from sklearn.metrics import mutual_info_score

# %%
mutual_info_score(df_full_train.churn, df_full_train.internetservice)
# Out:
# 0.055867945893496467

# %%
mutual_info_score(df_full_train.churn, df_full_train.contract)
# Out:
# 0.0983203874041556

# %%
def mutual_info_churn_score(series):
    return mutual_info_score(series, df_full_train.churn)

# %%
#For each column in the list of values in categorical, we apply this function
df_full_train[categorical].apply(mutual_info_churn_score)

mi = df_full_train[categorical].apply(mutual_info_churn_score)
mi.sort_values(ascending=False)
# Out:
# contract            0.098320
# onlinesecurity      0.063085
# techsupport         0.061032
# internetservice     0.055868
# onlinebackup        0.046923
# deviceprotection    0.043453
# paymentmethod       0.043210
# streamingtv         0.031853
# streamingmovies     0.031581
# paperlessbilling    0.017589
# dependents          0.012346
# partner             0.009968
# seniorcitizen       0.009410
# multiplelines       0.000857
# phoneservice        0.000229
# gender              0.000117
# dtype: float64

# %% [markdown]
# Correlation

# %%
df_full_train[numerical].corrwith(df_full_train.churn)
# Out:
# tenure           -0.351885
# monthlycharges    0.196805
# totalcharges     -0.196353
# dtype: float64

# %% [markdown]
# One-hot encoding

# %%
df_full_train[df_full_train.tenure <= 2].churn.mean()
# Out:
# np.float64(0.5953420669577875)

# %%
df_full_train[df_full_train.tenure > 12].churn.mean()
# Out:
# np.float64(0.17634908339788277)

# %%
from sklearn.feature_extraction import DictVectorizer
df_train[['gender', 'contract', 'tenure']].iloc[:100]
# Out:
#     gender        contract  tenure
# 0   female        two_year      72
# 1     male  month-to-month      10
# 2   female  month-to-month       5
# 3   female  month-to-month       5
# 4   female        two_year      18
# ..     ...             ...     ...
# 95    male        one_year      39
# 96  female  month-to-month      19
# 97    male  month-to-month      21
# 98    male        one_year      43
# 99    male  month-to-month      19
#
# [100 rows x 3 columns]

# %%
train_dicts = df_train[categorical + numerical].to_dict(orient='records')
train_dicts
# Out:
# [{'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 72,
#   'monthlycharges': 115.5,
#   'totalcharges': 8425.15},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 10,
#   'monthlycharges': 95.25,
#   'totalcharges': 1021.55},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 5,
#   'monthlycharges': 75.55,
#   'totalcharges': 413.65},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 5,
#   'monthlycharges': 80.85,
#   'totalcharges': 356.1},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 18,
#   'monthlycharges': 20.1,
#   'totalcharges': 370.5},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 4,
#   'monthlycharges': 30.5,
#   'totalcharges': 118.4},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 75.1,
#   'totalcharges': 75.1},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 70.3,
#   'totalcharges': 70.3},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 72,
#   'monthlycharges': 19.75,
#   'totalcharges': 1567.0},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 6,
#   'monthlycharges': 109.9,
#   'totalcharges': 669.45},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 72,
#   'monthlycharges': 99.9,
#   'totalcharges': 7251.7},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 17,
#   'monthlycharges': 102.55,
#   'totalcharges': 1742.5},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 66,
#   'monthlycharges': 58.2,
#   'totalcharges': 3810.8},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 2,
#   'monthlycharges': 68.95,
#   'totalcharges': 119.75},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 4,
#   'monthlycharges': 20.15,
#   'totalcharges': 84.5},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 3,
#   'monthlycharges': 70.7,
#   'totalcharges': 225.65},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 71,
#   'monthlycharges': 19.6,
#   'totalcharges': 1416.5},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 32,
#   'monthlycharges': 90.95,
#   'totalcharges': 2897.95},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 53,
#   'monthlycharges': 105.25,
#   'totalcharges': 5576.3},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 56,
#   'monthlycharges': 103.2,
#   'totalcharges': 5873.75},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 61,
#   'monthlycharges': 106.45,
#   'totalcharges': 6300.15},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 41,
#   'monthlycharges': 50.05,
#   'totalcharges': 2029.05},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 1,
#   'monthlycharges': 44.9,
#   'totalcharges': 44.9},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 3,
#   'monthlycharges': 71.1,
#   'totalcharges': 213.35},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 3,
#   'monthlycharges': 94.6,
#   'totalcharges': 279.55},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 12,
#   'monthlycharges': 21.05,
#   'totalcharges': 262.05},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 41,
#   'monthlycharges': 98.05,
#   'totalcharges': 3990.6},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 47,
#   'monthlycharges': 85.2,
#   'totalcharges': 3969.35},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 2,
#   'monthlycharges': 20.3,
#   'totalcharges': 41.2},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 66,
#   'monthlycharges': 70.85,
#   'totalcharges': 4738.85},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 8,
#   'monthlycharges': 59.25,
#   'totalcharges': 436.6},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 1,
#   'monthlycharges': 19.9,
#   'totalcharges': 19.9},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 35,
#   'monthlycharges': 40.9,
#   'totalcharges': 1383.6},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 67,
#   'monthlycharges': 107.05,
#   'totalcharges': 7142.5},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 1,
#   'monthlycharges': 31.35,
#   'totalcharges': 31.35},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 46,
#   'monthlycharges': 103.15,
#   'totalcharges': 4594.65},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 37,
#   'monthlycharges': 80.05,
#   'totalcharges': 3019.1},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 72,
#   'monthlycharges': 90.6,
#   'totalcharges': 6441.85},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 35,
#   'monthlycharges': 75.35,
#   'totalcharges': 2636.05},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 43,
#   'monthlycharges': 94.1,
#   'totalcharges': 4107.3},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 20,
#   'monthlycharges': 20.35,
#   'totalcharges': 442.6},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 64,
#   'monthlycharges': 81.05,
#   'totalcharges': 5135.35},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 6,
#   'monthlycharges': 44.4,
#   'totalcharges': 263.05},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 9,
#   'monthlycharges': 55.35,
#   'totalcharges': 449.75},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 18,
#   'monthlycharges': 25.55,
#   'totalcharges': 467.85},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 46,
#   'monthlycharges': 94.15,
#   'totalcharges': 4408.45},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 9,
#   'monthlycharges': 70.05,
#   'totalcharges': 564.4},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 69,
#   'monthlycharges': 20.15,
#   'totalcharges': 1337.5},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 32,
#   'monthlycharges': 19.45,
#   'totalcharges': 674.55},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 67,
#   'monthlycharges': 75.5,
#   'totalcharges': 5229.45},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 69,
#   'monthlycharges': 80.65,
#   'totalcharges': 5542.55},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 6,
#   'monthlycharges': 80.5,
#   'totalcharges': 463.05},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 30,
#   'monthlycharges': 40.35,
#   'totalcharges': 1187.05},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 30,
#   'monthlycharges': 54.45,
#   'totalcharges': 1588.7},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 58,
#   'monthlycharges': 45.35,
#   'totalcharges': 2540.1},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 18,
#   'monthlycharges': 90.1,
#   'totalcharges': 1612.75},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 34,
#   'monthlycharges': 71.55,
#   'totalcharges': 2427.35},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 2,
#   'monthlycharges': 20.2,
#   'totalcharges': 34.75},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 10,
#   'monthlycharges': 20.15,
#   'totalcharges': 220.8},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 71,
#   'monthlycharges': 99.0,
#   'totalcharges': 7061.65},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 72,
#   'monthlycharges': 60.95,
#   'totalcharges': 4549.05},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 46,
#   'monthlycharges': 21.1,
#   'totalcharges': 937.1},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 49,
#   'monthlycharges': 74.6,
#   'totalcharges': 3720.35},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 65,
#   'monthlycharges': 59.95,
#   'totalcharges': 3921.1},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 15,
#   'monthlycharges': 74.9,
#   'totalcharges': 1107.25},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 58,
#   'monthlycharges': 103.25,
#   'totalcharges': 6017.65},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 66,
#   'monthlycharges': 54.8,
#   'totalcharges': 3465.7},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 66,
#   'monthlycharges': 19.7,
#   'totalcharges': 1253.8},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 68,
#   'monthlycharges': 19.5,
#   'totalcharges': 1193.55},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 45,
#   'monthlycharges': 102.15,
#   'totalcharges': 4735.35},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 1,
#   'monthlycharges': 20.2,
#   'totalcharges': 20.2},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 11,
#   'monthlycharges': 79.5,
#   'totalcharges': 795.65},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 18,
#   'monthlycharges': 99.75,
#   'totalcharges': 1836.25},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 71,
#   'monthlycharges': 97.2,
#   'totalcharges': 6910.3},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 4,
#   'monthlycharges': 80.8,
#   'totalcharges': 332.45},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 13,
#   'monthlycharges': 56.0,
#   'totalcharges': 764.55},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 50,
#   'monthlycharges': 20.15,
#   'totalcharges': 970.85},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 12,
#   'monthlycharges': 50.95,
#   'totalcharges': 605.75},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 1,
#   'monthlycharges': 43.85,
#   'totalcharges': 43.85},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 7,
#   'monthlycharges': 19.9,
#   'totalcharges': 173.15},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 71,
#   'monthlycharges': 105.75,
#   'totalcharges': 7382.85},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 80.55,
#   'totalcharges': 80.55},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 21,
#   'monthlycharges': 104.35,
#   'totalcharges': 2271.85},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 12,
#   'monthlycharges': 86.55,
#   'totalcharges': 1066.9},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 50.5,
#   'totalcharges': 50.5},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 33,
#   'monthlycharges': 95.0,
#   'totalcharges': 3008.15},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 46,
#   'monthlycharges': 72.8,
#   'totalcharges': 3249.4},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 44,
#   'monthlycharges': 61.5,
#   'totalcharges': 2722.2},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 70,
#   'monthlycharges': 88.55,
#   'totalcharges': 6306.5},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 7,
#   'monthlycharges': 49.75,
#   'totalcharges': 331.3},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 18,
#   'monthlycharges': 69.8,
#   'totalcharges': 1221.65},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 54,
#   'monthlycharges': 65.25,
#   'totalcharges': 3529.95},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 35,
#   'monthlycharges': 33.45,
#   'totalcharges': 1175.85},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 5,
#   'monthlycharges': 70.25,
#   'totalcharges': 331.9},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
# ...
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 53,
#   'monthlycharges': 20.8,
#   'totalcharges': 1021.8},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 48,
#   'monthlycharges': 83.45,
#   'totalcharges': 3887.85},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 14,
#   'monthlycharges': 70.2,
#   'totalcharges': 1046.5},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 46,
#   'monthlycharges': 54.35,
#   'totalcharges': 2460.15},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 49,
#   'monthlycharges': 52.15,
#   'totalcharges': 2583.75},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 2,
#   'monthlycharges': 100.2,
#   'totalcharges': 198.5},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 19,
#   'monthlycharges': 20.5,
#   'totalcharges': 398.55},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 25.2,
#   'totalcharges': 25.2},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 72,
#   'monthlycharges': 84.45,
#   'totalcharges': 5899.85},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 72,
#   'monthlycharges': 84.45,
#   'totalcharges': 6033.1},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 5,
#   'monthlycharges': 85.4,
#   'totalcharges': 401.1},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 29,
#   'monthlycharges': 98.6,
#   'totalcharges': 2933.2},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 46,
#   'monthlycharges': 108.65,
#   'totalcharges': 4903.2},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 10,
#   'monthlycharges': 36.25,
#   'totalcharges': 374.0},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 66,
#   'monthlycharges': 89.0,
#   'totalcharges': 5898.6},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 34,
#   'monthlycharges': 77.2,
#   'totalcharges': 2753.8},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 1,
#   'monthlycharges': 45.95,
#   'totalcharges': 45.95},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 5,
#   'monthlycharges': 89.8,
#   'totalcharges': 502.6},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 66,
#   'monthlycharges': 65.7,
#   'totalcharges': 4378.9},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 46,
#   'monthlycharges': 19.95,
#   'totalcharges': 862.4},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 1,
#   'monthlycharges': 19.75,
#   'totalcharges': 19.75},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 18,
#   'monthlycharges': 85.45,
#   'totalcharges': 1505.85},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 9,
#   'monthlycharges': 55.3,
#   'totalcharges': 501.2},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 34,
#   'monthlycharges': 64.4,
#   'totalcharges': 2088.75},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 72,
#   'monthlycharges': 89.05,
#   'totalcharges': 6254.45},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 37,
#   'monthlycharges': 20.35,
#   'totalcharges': 697.65},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 38,
#   'monthlycharges': 20.1,
#   'totalcharges': 730.1},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 68,
#   'monthlycharges': 110.2,
#   'totalcharges': 7467.5},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 71,
#   'monthlycharges': 82.0,
#   'totalcharges': 5999.85},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 72,
#   'monthlycharges': 85.15,
#   'totalcharges': 6316.2},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 49,
#   'monthlycharges': 95.6,
#   'totalcharges': 4783.5},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 65,
#   'monthlycharges': 100.75,
#   'totalcharges': 6674.65},
#  ...]

# %%
dv= DictVectorizer(sparse=False)

# %%
dv.fit(train_dicts)
# Out:
# DictVectorizer(sparse=False)

# %%
dv.get_feature_names_out()
# Out:
# array(['contract=month-to-month', 'contract=one_year',
#        'contract=two_year', 'dependents=no', 'dependents=yes',
#        'deviceprotection=no', 'deviceprotection=no_internet_service',
#        'deviceprotection=yes', 'gender=female', 'gender=male',
#        'internetservice=dsl', 'internetservice=fiber_optic',
#        'internetservice=no', 'monthlycharges', 'multiplelines=no',
#        'multiplelines=no_phone_service', 'multiplelines=yes',
#        'onlinebackup=no', 'onlinebackup=no_internet_service',
#        'onlinebackup=yes', 'onlinesecurity=no',
#        'onlinesecurity=no_internet_service', 'onlinesecurity=yes',
#        'paperlessbilling=no', 'paperlessbilling=yes', 'partner=no',
#        'partner=yes', 'paymentmethod=bank_transfer_(automatic)',
#        'paymentmethod=credit_card_(automatic)',
#        'paymentmethod=electronic_check', 'paymentmethod=mailed_check',
#        'phoneservice=no', 'phoneservice=yes', 'seniorcitizen',
#        'streamingmovies=no', 'streamingmovies=no_internet_service',
#        'streamingmovies=yes', 'streamingtv=no',
#        'streamingtv=no_internet_service', 'streamingtv=yes',
#        'techsupport=no', 'techsupport=no_internet_service',
#        'techsupport=yes', 'tenure', 'totalcharges'], dtype=object)

# %%
dv.transform(train_dicts)
X_train = dv.transform(train_dicts)

# %%
#faster method
X_train = dv.fit_transform(train_dicts)

# %%
#only transform for validation set
val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)
X_val
# Out:
# array([[0.0000e+00, 0.0000e+00, 1.0000e+00, ..., 1.0000e+00, 7.1000e+01,
#         4.9734e+03],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 1.0000e+00,
#         2.0750e+01],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 1.0000e+00,
#         2.0350e+01],
#        ...,
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.0000e+00, 1.8000e+01,
#         1.0581e+03],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 1.0000e+00,
#         9.3300e+01],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 3.0000e+00,
#         2.9285e+02]], shape=(1409, 45))

# %% [markdown]
# Logistic Regression

# %%
def sigmoid(z):
    return 1/(1+ np.exp(-z))

# %%
z = np.linspace(-5, 5, 51)

sigmoid(z)
# Out:
# array([0.00669285, 0.00816257, 0.0099518 , 0.01212843, 0.01477403,
#        0.01798621, 0.02188127, 0.02659699, 0.03229546, 0.03916572,
#        0.04742587, 0.05732418, 0.06913842, 0.0831727 , 0.09975049,
#        0.11920292, 0.14185106, 0.16798161, 0.19781611, 0.23147522,
#        0.26894142, 0.31002552, 0.35434369, 0.40131234, 0.450166  ,
#        0.5       , 0.549834  , 0.59868766, 0.64565631, 0.68997448,
#        0.73105858, 0.76852478, 0.80218389, 0.83201839, 0.85814894,
#        0.88079708, 0.90024951, 0.9168273 , 0.93086158, 0.94267582,
#        0.95257413, 0.96083428, 0.96770454, 0.97340301, 0.97811873,
#        0.98201379, 0.98522597, 0.98787157, 0.9900482 , 0.99183743,
#        0.99330715])

# %%
def linear_regression(xi):
    result = w0
    
    for j in range(len(w)):
        result = result + xi[j] * w[j]
    return result

# %%
def logistic_regression(xi):
    score = w0
    
    for j in range(len(w)):
        score = score + xi[j] * w[j]
        
        
    reulst = sigmoid(score)   
    return result

# %% [markdown]
# Training Logistic Regression with Scikit-Learn

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=10000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
#Bias and intercept are synonyms
model.intercept_[0]
# Out:
# np.float64(-0.045323382519725265)

# %%
model.coef_[0]
# Out:
# array([ 6.84563865e-01,  3.85627805e-02, -6.82106720e-01,  5.59874182e-02,
#        -1.49674921e-02,  1.13934134e-01, -1.59961569e-01,  8.70473614e-02,
#         3.94140853e-02,  1.60584095e-03, -4.97473553e-01,  6.98455049e-01,
#        -1.59961569e-01, -1.79930514e-02, -1.87166364e-01,  6.61224966e-02,
#         1.62063794e-01,  1.16725547e-01, -1.59961569e-01,  8.42559483e-02,
#         2.85032504e-01, -1.59961569e-01, -8.40510084e-02, -1.61238079e-01,
#         2.02258005e-01, -4.45575410e-02,  8.55774672e-02, -5.15350530e-02,
#        -2.96985505e-03,  1.06354594e-01, -1.08297599e-02,  6.61224966e-02,
#        -2.51025705e-02,  1.93985926e-01, -9.41528635e-02, -1.59961569e-01,
#         2.95134358e-01, -5.39335450e-02, -1.59961569e-01,  2.54915040e-01,
#         2.35033033e-01, -1.59961569e-01, -3.40515382e-02, -6.85347146e-02,
#         3.95932211e-04])

# %%
#Hard predictions
model.predict(X_train)
# Out:
# array([0, 1, 1, ..., 1, 0, 1], shape=(4225,))

# %%
#Soft probability, since it gives us a probability value between 0 and 1, instead of a hard value of 0 or 1
#Two columns, 1st is probability of 0 or negative, in this cae not churning, second column is probability of churning, so the probability 
#of the score being 1
model.predict_proba(X_val)
# Out:
# array([[0.9933762 , 0.0066238 ],
#        [0.79517747, 0.20482253],
#        [0.78218201, 0.21781799],
#        ...,
#        [0.84850356, 0.15149644],
#        [0.21152144, 0.78847856],
#        [0.18809609, 0.81190391]], shape=(1409, 2))

# %%
#Grab the second column, which the probability of churning
y_pred = model.predict_proba(X_val)[:,1]

# %%
churn_decision = (y_pred >= 0.5)
df_val[churn_decision].customerid
# Out:
# 3       8433-wxgna
# 8       3440-jpscl
# 12      7228-omtpn
# 19      6711-fldfb
# 24      2612-ranwt
#            ...
# 1397    5976-jcjrh
# 1398    2034-cgrhz
# 1399    5276-kqwhg
# 1407    6521-yytyi
# 1408    3049-solay
# Name: customerid, Length: 315, dtype: object

# %%
(y_val == churn_decision).mean()
# Out:
# np.float64(0.8034066713981547)

# %%
df_pred = pd.DataFrame()
df_pred['probability'] = y_pred
df_pred['prediction'] = churn_decision.astype(int)
df_pred['actual'] = y_val

# %%
df_pred['correct'] = df_pred['prediction'] == df_pred['actual']
df_pred['correct']
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1404     True
# 1405    False
# 1406     True
# 1407     True
# 1408     True
# Name: correct, Length: 1409, dtype: bool

# %%
df_pred.correct.mean()
# Out:
# np.float64(0.8034066713981547)

# %%
churn_decision.astype(int)
# Out:
# array([0, 0, 0, ..., 0, 1, 1], shape=(1409,))

# %% [markdown]
#  Model Interpretation

# %%
a = [1, 2, 3, 4]
b = 'abcd'

# %%
dict(zip(a,b))
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %%
dict(zip(dv.get_feature_names_out(), model.coef_[0].round(3)))
# Out:
# {'contract=month-to-month': np.float64(0.685),
#  'contract=one_year': np.float64(0.039),
#  'contract=two_year': np.float64(-0.682),
#  'dependents=no': np.float64(0.056),
#  'dependents=yes': np.float64(-0.015),
#  'deviceprotection=no': np.float64(0.114),
#  'deviceprotection=no_internet_service': np.float64(-0.16),
#  'deviceprotection=yes': np.float64(0.087),
#  'gender=female': np.float64(0.039),
#  'gender=male': np.float64(0.002),
#  'internetservice=dsl': np.float64(-0.497),
#  'internetservice=fiber_optic': np.float64(0.698),
#  'internetservice=no': np.float64(-0.16),
#  'monthlycharges': np.float64(-0.018),
#  'multiplelines=no': np.float64(-0.187),
#  'multiplelines=no_phone_service': np.float64(0.066),
#  'multiplelines=yes': np.float64(0.162),
#  'onlinebackup=no': np.float64(0.117),
#  'onlinebackup=no_internet_service': np.float64(-0.16),
#  'onlinebackup=yes': np.float64(0.084),
#  'onlinesecurity=no': np.float64(0.285),
#  'onlinesecurity=no_internet_service': np.float64(-0.16),
#  'onlinesecurity=yes': np.float64(-0.084),
#  'paperlessbilling=no': np.float64(-0.161),
#  'paperlessbilling=yes': np.float64(0.202),
#  'partner=no': np.float64(-0.045),
#  'partner=yes': np.float64(0.086),
#  'paymentmethod=bank_transfer_(automatic)': np.float64(-0.052),
#  'paymentmethod=credit_card_(automatic)': np.float64(-0.003),
#  'paymentmethod=electronic_check': np.float64(0.106),
#  'paymentmethod=mailed_check': np.float64(-0.011),
#  'phoneservice=no': np.float64(0.066),
#  'phoneservice=yes': np.float64(-0.025),
#  'seniorcitizen': np.float64(0.194),
#  'streamingmovies=no': np.float64(-0.094),
#  'streamingmovies=no_internet_service': np.float64(-0.16),
#  'streamingmovies=yes': np.float64(0.295),
#  'streamingtv=no': np.float64(-0.054),
#  'streamingtv=no_internet_service': np.float64(-0.16),
#  'streamingtv=yes': np.float64(0.255),
#  'techsupport=no': np.float64(0.235),
#  'techsupport=no_internet_service': np.float64(-0.16),
#  'techsupport=yes': np.float64(-0.034),
#  'tenure': np.float64(-0.069),
#  'totalcharges': np.float64(0.0)}

# %%
small = ['contract', 'tenure', 'monthlycharges']
df_train[small].iloc[:10].to_dict(orient='records')
# Out:
# [{'contract': 'two_year', 'tenure': 72, 'monthlycharges': 115.5},
#  {'contract': 'month-to-month', 'tenure': 10, 'monthlycharges': 95.25},
#  {'contract': 'month-to-month', 'tenure': 5, 'monthlycharges': 75.55},
#  {'contract': 'month-to-month', 'tenure': 5, 'monthlycharges': 80.85},
#  {'contract': 'two_year', 'tenure': 18, 'monthlycharges': 20.1},
#  {'contract': 'month-to-month', 'tenure': 4, 'monthlycharges': 30.5},
#  {'contract': 'month-to-month', 'tenure': 1, 'monthlycharges': 75.1},
#  {'contract': 'month-to-month', 'tenure': 1, 'monthlycharges': 70.3},
#  {'contract': 'two_year', 'tenure': 72, 'monthlycharges': 19.75},
#  {'contract': 'month-to-month', 'tenure': 6, 'monthlycharges': 109.9}]

# %%
dicts_train_small = df_train[small].to_dict(orient='records')
dicts_val_small = df_val[small].to_dict(orient='records')

# %%
dv_small = DictVectorizer(sparse=False)
dv_small.fit(dicts_train_small)
# Out:
# DictVectorizer(sparse=False)

# %%
dv_small.get_feature_names_out()
# Out:
# array(['contract=month-to-month', 'contract=one_year',
#        'contract=two_year', 'monthlycharges', 'tenure'], dtype=object)

# %%
X_train_small = dv_small.transform(dicts_train_small)

# %%
model_small = LogisticRegression()
model_small.fit(X_train_small, y_train)
# Out:
# LogisticRegression()

# %%
w0 = model_small.intercept_[0]
w0
# Out:
# np.float64(-2.477957595829565)

# %%
w = model_small.coef_[0]
w
# Out:
# array([ 0.9711394 , -0.02379507, -0.94828863,  0.02748534, -0.03619005])

# %%
dict(zip(dv_small.get_feature_names_out(), w.round(3)))
# Out:
# {'contract=month-to-month': np.float64(0.971),
#  'contract=one_year': np.float64(-0.024),
#  'contract=two_year': np.float64(-0.948),
#  'monthlycharges': np.float64(0.027),
#  'tenure': np.float64(-0.036)}

# %%
-2.47 + 0.97 + 50 * 0.027 + 5 * (-0.036)
# Out:
# -0.3300000000000001

# %%
sigmoid(_)
# Out:
# np.float64(0.41824062315816374)

# %% [markdown]
# Using the model

# %%
dicts_full_train = df_full_train[categorical + numerical].to_dict(orient='records')
dicts_full_train[:3]
# Out:
# [{'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 12,
#   'monthlycharges': 19.7,
#   'totalcharges': 258.35},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 42,
#   'monthlycharges': 73.9,
#   'totalcharges': 3160.55},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 71,
#   'monthlycharges': 65.15,
#   'totalcharges': 4681.75}]

# %%
dv = DictVectorizer(sparse=False)
X_full_train = dv.fit_transform(dicts_full_train)
y_full_train = df_full_train.churn.values

# %%
model = LogisticRegression(max_iter=10000).fit(X_full_train, y_full_train)

# %%
dict_test = df_test[categorical + numerical].to_dict(orient='records')
X_test = dv.transform(dict_test)

# %%
y_pred = model.predict_proba(X_test)[:, 1]

# %%
churn_decision = (y_pred >= 0.5)

# %%
(churn_decision == y_test).mean()
# Out:
# np.float64(0.8105039034776437)

# %%
customer = dict_test[10]

# %%
X_small = dv.transform([customer])
X_small.shape
# Out:
# (1, 45)

# %%
model.predict_proba(X_small)[0,1]
# Out:
# np.float64(0.47632824241018595)

# %%
dict_full = df[categorical + numerical].to_dict(orient='records')
X_full = dv.transform(dict_full)

# %%
predictions = model.predict_proba(X_full)[:, 1]

# %%
(predictions >= 0.5).mean()
# Out:
# np.float64(0.22745988925173932)

# %%
total_predictions = dict(zip(df['customerid'], predictions))
# Out:
# {'7590-vhveg': np.float64(0.6275953527536646),
#  '5575-gnvde': np.float64(0.043535213136196564),
#  '3668-qpybk': np.float64(0.29857382644133634),
#  '7795-cfocw': np.float64(0.0279486051424715),
#  '9237-hqitu': np.float64(0.7027650740019229),
#  '9305-cdskc': np.float64(0.7727980874216942),
#  '1452-kiovk': np.float64(0.4969467416422243),
#  '6713-okomc': np.float64(0.30217452943615464),
#  '7892-pookp': np.float64(0.6050386866388893),
#  '6388-tabgu': np.float64(0.012171653598398242),
#  '9763-grskd': np.float64(0.22860451373361604),
#  '7469-lkbci': np.float64(0.02718160367487174),
#  '8091-ttvax': np.float64(0.18356554829845664),
#  '0280-xjgex': np.float64(0.40459342028847245),
#  '5129-jlpis': np.float64(0.45440577298262597),
#  '3655-snqyz': np.float64(0.041718271536535324),
#  '8191-xwszg': np.float64(0.00822248355201389),
#  '9959-wofkt': np.float64(0.05103979968982912),
#  '4190-mfluw': np.float64(0.19904406618454282),
#  '4183-myfrb': np.float64(0.5578515410518268),
#  '8779-qrdmv': np.float64(0.7287048735303466),
#  '1680-vdcww': np.float64(0.07192177667256666),
#  '1066-jksgk': np.float64(0.20268298481273073),
#  '3638-weabw': np.float64(0.014518351788693089),
#  '6322-hrpfa': np.float64(0.029895757768861216),
#  '6865-jznko': np.float64(0.11654785021180075),
#  '6467-chfzw': np.float64(0.49940899101166314),
#  '8665-utdhz': np.float64(0.5253409861892642),
#  '5248-ygijn': np.float64(0.014281135633045733),
#  '8773-hhuoz': np.float64(0.3694183496471665),
#  '3841-nfecx': np.float64(0.03140855929717764),
#  '4929-xihvw': np.float64(0.7353357092945892),
#  '6827-ieauq': np.float64(0.03891729067164034),
#  '7310-egvhz': np.float64(0.20930007165583384),
#  '3413-bmnze': np.float64(0.4174712389425757),
#  '6234-raapl': np.float64(0.025092998197400455),
#  '6047-yhpvi': np.float64(0.6678109178255746),
#  '6572-adkrs': np.float64(0.2464629139261199),
#  '5380-wjkov': np.float64(0.5835780173378439),
#  '8168-uqwwf': np.float64(0.6970226702049761),
#  '8865-tnmnx': np.float64(0.13738293956758),
#  '9489-dedvp': np.float64(0.011487495740995952),
#  '9867-jczsp': np.float64(0.053847117390856215),
#  '4671-vjlcl': np.float64(0.011690641246804565),
#  '4080-iiard': np.float64(0.30501612687934204),
#  '3714-ntnfo': np.float64(0.42598069706697317),
#  '5948-ujzlf': np.float64(0.3105163600018334),
#  '7760-oypdy': np.float64(0.7293385726932137),
#  '7639-liayi': np.float64(0.029598753824500775),
#  '2954-pibko': np.float64(0.006693627281578049),
#  '8012-soudq': np.float64(0.4878087569095707),
